# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /home/user/miniconda3/envs/llm-project/bin/python
# 3.11.16 (main, Aug 27 2026, 14:44:21) [GCC 14.3.0]

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /home/user/miniconda3/envs/llm-project/bin/python
# 3.11.16 (main, Aug 27 2026, 14:44:21) [GCC 14.3.0]

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("OpenAI key loaded:", bool(os.getenv("OPENAI_API_KEY")))
# Out:
# OpenAI key loaded: True

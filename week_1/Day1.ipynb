# %%
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What's the capital of France?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from openai import OpenAI
#       2 from dotenv import load_dotenv
#       3 import os
#       4
#
# ModuleNotFoundError: No module named 'openai'

# %%
print("hello world!")
print("python is a programming language!")
# Out:
# hello world!
# python is a programming language!

# %%
import math

# %%
from dotenv import main


result = math.sqrt(29)
print(result)
# Out:
# 5.385164807134504

# %%
import math  # Imports the entire math module
from random import randint  # Only imports randint from random

# Using math.pi
print("Pi:", math.pi)  # Output: 3.141592653589793

# Using randint directly
print("Random integer:", randint(1, 10))  # Output: A random number between 1 and 10
# Out:
# Pi: 3.141592653589793
# Random integer: 10

# %%
# Creating a list of fruits
fruits = ["apple", "banana", "cherry"]

# Accessing items
print(fruits[0])  # Output: apple
print(fruits[1])  # Output: banana

# Adding an item
fruits.append("orange")
print(fruits)  # Output: ['apple', 'banana', 'cherry', 'orange']

# Removing an item
fruits.remove("banana")
print(fruits)  # Output: ['apple', 'cherry', 'orange']
# Out:
# apple
# banana
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'cherry', 'orange']

# %%
# Creating a dictionary with some information about a person
person = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}

# Accessing values by key
print(person["name"])  # Output: Alice
print(person["age"])   # Output: 25

# Adding a new key-value pair
person["job"] = "Engineer"
print(person)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York', 'job': 'Engineer'}

# Changing a value
person["city"] = "San Francisco"
print(person)  # Output: {'name': 'Alice', 'age': 25, 'city': 'San Francisco', 'job': 'Engineer'}
# Out:
# Alice
# 25
# {'name': 'Alice', 'age': 25, 'city': 'New York', 'job': 'Engineer'}
# {'name': 'Alice', 'age': 25, 'city': 'San Francisco', 'job': 'Engineer'}

# %%
# Using get() without a default value
print(person.get("name"))  # Output: Alice
print(person.get("country"))  # Output: None (since 'country' is not a key)

# Using get() with a default value
print(person.get("country", "USA"))  # Output: USA (default value provided)
# Out:
# Alice
# None
# USA

# %%
# Creating a set of colors
colors = {"red", "green", "blue"}

# Adding an item
colors.add("yellow")
print(colors)  # Output: {'red', 'green', 'blue', 'yellow'}

# Trying to add a duplicate item
colors.add("red")
print(colors)  # Output: {'red', 'green', 'blue', 'yellow'} (no duplicate)

# Removing an item
colors.remove("green")
print(colors)  # Output: {'red', 'blue', 'yellow'}
# Out:
# {'green', 'blue', 'yellow', 'red'}
# {'green', 'blue', 'yellow', 'red'}
# {'blue', 'yellow', 'red'}

# %%
file = open('my_note.txt','r', encoding='utf-8')

# %%
with open('my_note.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    print(content)
# Out:
# Hello!
# My name is AValumun Sekulla Nyior.
# I am learning Python.
# Python is fun!

# %%
with open('my_note.txt', 'w', encoding='utf-8') as file:
    file.write("Hello, World!")

# %%
with open('my_note.txt', 'a', encoding='utf-8') as file:
    file.write("\nThis is an appended line.")

# %%
with open('my_note.txt', 'r', encoding='utf-8') as file:
    for line in file:
        print(line.strip())
# Out:
# My name is AValumun Sekulla Nyior.
# I am learning Python.
# Python is a programming language.
# I am currently learning how to work with files.
# Files allow programs to store information.
# A text file can contain words, numbers, and symbols.
# Python can read information from a text file.
# Python can also write information to a text file.
# The open() function is used to open a file.
# The letter r means read.
# The letter w means write.
# The letter a means append.
# Using with is a good way to work with files.
# A context manager automatically closes the file.
# The pathlib library helps us work with file paths.
# The glob library can help us find files.
# Learning Python takes practice.
# Making mistakes is part of learning.
# The more I practice, the better I will become.
# I am getting more comfortable with Python every day.
#
# This is an appended line.

# %%
with open('my_note.txt', 'r', encoding='utf-8') as file:
    for line in file:
        print(line)
# Out:
# My name is AValumun Sekulla Nyior.
#
# I am learning Python.
#
# Python is a programming language.
#
# I am currently learning how to work with files.
#
# Files allow programs to store information.
#
# A text file can contain words, numbers, and symbols.
#
# Python can read information from a text file.
#
# Python can also write information to a text file.
#
# The open() function is used to open a file.
#
# The letter r means read.
#
# The letter w means write.
#
# The letter a means append.
#
# Using with is a good way to work with files.
#
# A context manager automatically closes the file.
#
# The pathlib library helps us work with file paths.
#
# The glob library can help us find files.
#
# Learning Python takes practice.
#
# Making mistakes is part of learning.
#
# The more I practice, the better I will become.
#
# I am getting more comfortable with Python every day.
#
#
#
# This is an appended line.

# %%
print(line.strip())
# Out:
# This is an appended line.

# %%
with open('my_note.txt', 'a', encoding='utf-8') as file:
    file.write("\nThis is an appended line.")

# %%
print(line.strip())
# Out:
# This is an appended line.

# %%
import os

# Construct a file path
file_path = os.path.join('folder', 'subfolder', 'my_note.txt')
print(file_path)
# Out:
# folder/subfolder/my_note.txt

# %%
from pathlib import Path

# Construct a file path
file_path = Path('folder') / 'subfolder' / 'my_note.txt'
print(file_path)

# Check if a file exists
if file_path.exists():
    print(f"{file_path} exists!")
# Out:
# folder/subfolder/my_note.txt

# %%
import glob

# List all .txt files in the current directory
txt_files = glob.glob('*.txt')
print(txt_files)
# Out:
# ['friends.txt', 'my_note.txt', 'fav_fruits.txt']

# %%
# List all .txt files in current directory and subdirectories
all_txt_files = glob.glob('**/*.txt', recursive=True)
print(all_txt_files)
# Out:
# ['friends.txt', 'my_note.txt', 'fav_fruits.txt']

# %%
from pathlib import Path
import glob

# Define file paths using pathlib
input_file = Path('data') / 'input.txt'
output_file = Path('data') / 'output.txt'

# Ensure the directory exists
output_file.parent.mkdir(parents=True, exist_ok=True)

# Read the input file and write to the output file
if input_file.exists():
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
        for line in infile:
            outfile.write(line.lower())  # Example: Write uppercase content
else:
    print(f"File {input_file} not found.")

# List all text files in the directory
txt_files = glob.glob(str(Path('data') / '*.txt'))
print("Text files in the 'data' directory:", txt_files)
# Out:
# Text files in the 'data' directory: ['data/input.txt', 'data/output.txt']

# %%
from datetime import datetime

current_date = datetime.now()
formatted_date = f"Today’s date is {current_date:%B %d, %Y}."
print(formatted_date)
# Out:
# Today’s date is September 14, 2026.

# %%
class Dog:
    pass

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def speak(self):
        print(f"{self.name} says woof!")

# %%
my_dog = Dog("Buddy", 3)

# %%
print(my_dog)
# Out:
# <__main__.Dog object at 0x7cd7c41d6250>

# %%
print(my_dog.name)  # Output: Buddy
print(my_dog.age)   # Output: 3
my_dog.speak()      # Output: Buddy says woof!
# Out:
# Buddy
# 3
# Buddy says woof!

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def summary(self):
        print(f"'{self.title}' by {self.author}, {self.pages} pages long.")

# %%
my_book = Book("To Kill a Mockingbird", "Harper Lee", 281)
print(my_book.title)        # Output: To Kill a Mockingbird
print(my_book.author)       # Output: Harper Lee
my_book.summary()           # Output: 'To Kill a Mockingbird' by Harper Lee, 281 pages long.
# Out:
# To Kill a Mockingbird
# Harper Lee
# 'To Kill a Mockingbird' by Harper Lee, 281 pages long.

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def description(self):
        return f"{self.year} {self.make} {self.model}"

    def start_engine(self):
        print(f"The engine of the {self.model} is now running.")

# Creating a Car object
my_car = Car("Toyota", "Camry", 2021)

# Accessing attributes and calling methods
print(my_car.description())  # Output: 2021 Toyota Camry
my_car.start_engine()        # Output: The engine of the Camry is now running.
# Out:
# 2021 Toyota Camry
# The engine of the Camry is now running.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f"Person(name={self.name}, age={self.age})"

# %%
import pickle

# Create an instance of the class
person = Person("Alice", 30)

# Open a file in binary write mode
with open("person.pkl", "wb") as file:
    pickle.dump(person, file)  # Serialize and write to file

print("Object pickled successfully.")
# Out:
# Object pickled successfully.

# %%
# Open the file in binary read mode
with open("person.pkl", "rb") as file:
    loaded_person = pickle.load(file)  # Deserialize and load

print("Loaded object:", loaded_person)
# Out:
# Loaded object: Person(name=Alice, age=30)

# %%
import json

# Example dictionary
data = {"name": "Alice", "age": 30, "hobbies": ["reading", "cycling"]}

# Save to a JSON file
with open("data.json", "w") as file:
    json.dump(data, file)

print("Data saved as JSON.")
# Out:
# Data saved as JSON.

# %%
# Read from the JSON file
with open("data.json", "r") as file:
    loaded_data = json.load(file)

print("Loaded JSON data:", loaded_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[56], line 3
#       1 # Read from the JSON file
#       2 with open("data.json", "r") as file:
# ----> 3     loaded_data = json.load(file)
#       4
#       5 print("Loaded JSON data:", loaded_data)
#
# File ~/miniconda3/envs/llm-project/lib/python3.11/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/miniconda3/envs/llm-project/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/envs/llm-project/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/miniconda3/envs/llm-project/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Convert Python object to JSON string
json_string = json.dumps(data)
print("JSON String:", json_string)

# Convert JSON string back to Python object
python_obj = json.loads(json_string)
print("Python Object:", python_obj)
# Out:
# JSON String: {"name": "Alice", "age": 30, "hobbies": ["reading", "cycling"]}
# Python Object: {'name': 'Alice', 'age': 30, 'hobbies': ['reading', 'cycling']}

# %%
raise ValueError("This is an example exception")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 raise ValueError("This is an example exception")
#
# ValueError: This is an example exception

# %%
try:
    # Code that might raise an exception
    risky_thing()
except SomeErrorType:
    # Code that runs if that exception occurs
    print("Caught an error!")
finally:
    # Code that always runs, whether or not an exception occurred
    print("Cleaning up...")
# Out:
# Cleaning up...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 9
#       7 finally:
#       8     # Code that always runs, whether or not an exception occurred
# ----> 9     print("Cleaning up...")
#
# NameError: name 'risky_thing' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 9
#       5     # Code that runs if that exception occurs
#       6     print("Caught an error!")
#       7 finally:
#       8     # Code that always runs, whether or not an exception occurred
# ----> 9     print("Cleaning up...")
#
# NameError: name 'SomeErrorType' is not defined

# %%
try:
    result = 5 / 0
except ZeroDivisionError:
    print("You can't divide by zero!")
finally:
    print("Done.")
# Out:
# You can't divide by zero!
# Done.

# %%
try:
    do_something()
except Exception as e:
    print(f"Something went wrong: {e}")
# Out:
# Something went wrong: name 'do_something' is not defined

# %%
def level_one():
    level_two()

def level_two():
    raise RuntimeError("Something bad happened.")

level_one()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[62], line 7
#       3
#       4 def level_two():
#       5     raise RuntimeError("Something bad happened.")
#       6
# ----> 7 level_one()
#
# Cell In[62], line 2, in level_one()
#       1 def level_one():
# ----> 2     level_two()
#
# Cell In[62], line 5, in level_two()
#       4 def level_two():
# ----> 5     raise RuntimeError("Something bad happened.")
#
# RuntimeError: Something bad happened.

# %%
# First let's create some things:

fruits = ["Apples", "Bananas", "Pears"]

book1 = {"title": "Great Expectations", "author": "Charles Dickens"}
book2 = {"title": "Bleak House", "author": "Charles Dickens"}
book3 = {"title": "An Book By No Author"}
book4 = {"title": "Moby Dick", "author": "Herman Melville"}

books = [book1, book2, book3, book4]

# %%
# Simple enough to start

for fruit in fruits:
    print(fruit)
# Out:
# Apples
# Bananas
# Pears

# %%
fruits_shouted = []
for fruit in fruits:
    fruits_shouted.append(fruit.upper())

fruits_shouted
# Out:
# ['APPLES', 'BANANAS', 'PEARS']

# %%
# You probably already know this
# There's a nice Python construct called "list comprehension" that does this:

fruits_shouted2 = [fruit.upper() for fruit in fruits]
fruits_shouted2
# Out:
# ['APPLES', 'BANANAS', 'PEARS']

# %%
# But you may not know that you can do this to create dictionaries, too:

fruit_mapping = {fruit: fruit.upper() for fruit in fruits}
fruit_mapping
# Out:
# {'Apples': 'APPLES', 'Bananas': 'BANANAS', 'Pears': 'PEARS'}

# %%
# you can also use the if statement to filter the results

fruits_with_longer_names_shouted = [fruit.upper() for fruit in fruits if len(fruit)>5]
fruits_with_longer_names_shouted
# Out:
# ['APPLES', 'BANANAS']

# %%
fruit_mapping_unless_starts_with_a = {fruit: fruit.upper() for fruit in fruits if not fruit.startswith('A')}
fruit_mapping_unless_starts_with_a
# Out:
# {'Bananas': 'BANANAS', 'Pears': 'PEARS'}

# %%
# Another comprehension

[book['title'] for book in books]
# Out:
# ['Great Expectations', 'Bleak House', 'An Book By No Author', 'Moby Dick']

# %%
 This code will fail with an error because one of our books doesn't have an author

[book['author'] for book in books]
# Out:
#   Cell In[12], line 1
#     This code will fail with an error because one of our books doesn't have an author
#     ^
# IndentationError: unexpected indent

# %%
# But this will work, because get() returns None

[book.get('author') for book in books]
# Out:
# ['Charles Dickens', 'Charles Dickens', None, 'Herman Melville']

# %%
# And this variation will filter out the None

[book.get('author') for book in books if book.get('author')]
# Out:
# ['Charles Dickens', 'Charles Dickens', 'Herman Melville']

# %%
# And this version will convert it into a set, removing duplicates

set([book.get('author') for book in books if book.get('author')])
# Out:
# {'Charles Dickens', 'Herman Melville'}

# %%
# And finally, this version is even nicer
# curly braces creates a set, so this is a set comprehension

{book.get('author') for book in books if book.get('author')}
# Out:
# {'Charles Dickens', 'Herman Melville'}

# %%
# First define a generator; it looks like a function, but it has yield instead of return

import time

def come_up_with_fruit_names():
    for fruit in fruits:
        time.sleep(1) # thinking of a fruit
        yield fruit

# %%
# Then use it

for fruit in come_up_with_fruit_names():
    print(fruit)
# Out:
# Apples
# Bananas
# Pears

# %%
# Here's another one

def authors_generator():
    for book in books:
        if book.get("author"):
            yield book.get("author")

# %%
for author in authors_generator():
    print(author)
# Out:
# Charles Dickens
# Charles Dickens
# Herman Melville

# %%
# Here's the same thing written with list comprehension

def authors_generator():
    for author in [book.get("author") for book in books if book.get("author")]:
        yield author

# %%
for author in authors_generator():
    print(author)
# Out:
# Charles Dickens
# Charles Dickens
# Herman Melville

# %%
# Here's a nice shortcut
# You can use "yield from" to yield each item of an iterable

def authors_generator():
    yield from [book.get("author") for book in books if book.get("author")]

# %%
# Use it

for author in authors_generator():
    print(author)
# Out:
# Charles Dickens
# Charles Dickens
# Herman Melville

# %%
# And finally - we can replace the list comprehension with a set comprehension

def unique_authors_generator():
    yield from {book.get("author") for book in books if book.get("author")}

# %%
# Use it

for author in unique_authors_generator():
    print(author)
# Out:
# Charles Dickens
# Herman Melville

# %%
# And for some fun - press the stop button in the toolbar when bored!
# It's like we've made our own Large Language Model... although not particularly large..
# See if you understand why it prints a letter at a time, instead of a word at a time. If you're unsure, try removing the keyword "from" everywhere in the code.

import random
import time

pronouns = ["I", "You", "We", "They"]
verbs = ["eat", "detest", "bathe in", "deny the existence of", "resent", "pontificate about", "juggle", "impersonate", "worship", "misplace", "conspire with", "philosophize about", "tap dance on", "dramatically renounce", "secretly collect"]
adjectives = ["turqoise", "smelly", "arrogant", "festering", "pleasing", "whimsical", "disheveled", "pretentious", "wobbly", "melodramatic", "pompous", "fluorescent", "bewildered", "suspicious", "overripe"]
nouns = ["turnips", "rodents", "eels", "walruses", "kumquats", "monocles", "spreadsheets", "bagpipes", "wombats", "accordions", "mustaches", "calculators", "jellyfish", "thermostats"]

def infinite_random_sentences():
    while True:
        yield from random.choice(pronouns)
        yield " "
        yield from random.choice(verbs)
        yield " "
        yield from random.choice(adjectives)
        yield " "
        yield from random.choice(nouns)
        yield ". "

for letter in infinite_random_sentences():
    print(letter, end="", flush=True)
    time.sleep(0.02)
# Out:
# We secretly collect overripe mustaches. We tap dance on smelly monocles. I philosophize about arrogant turnips. They conspire with fluorescent eels. They resent whimsical accordions. I resent festering monocles. We impersonate smelly walruses. I resent arrogant mustaches. They juggle smelly calculators. We conspire with bewildered bagpipes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 26
#      22         yield ". "
#      23
#      24 for letter in infinite_random_sentences():
#      25     print(letter, end="", flush=True)
# ---> 26     time.sleep(0.02)
#
# KeyboardInterrupt:

# %%
class LibraryItem:
    title: str
    year: int

    def __init__(self, title: str, year: int):
        self.title = title
        self.year = year

    def get_info(self) -> str:
        return f"{self.title} ({self.year})"

class Book(LibraryItem):
    author: str

    def __init__(self, title: str, year: int, author: str):
        super().__init__(title, year)
        self.author = author

    def get_info(self) -> str:
        return f"'{self.title}' by {self.author} ({self.year})"

    @classmethod
    def from_string(cls, info: str) -> 'Book':
        title, author, year = info.split(', ')
        return cls(title, int(year), author)

# Using the class method and the subclass
book = Book.from_string("The Catcher in the Rye, J.D. Salinger, 1951")
print(book.get_info())
# Out:
# 'The Catcher in the Rye' by J.D. Salinger (1951)

# %%
#imports
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

messages = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": messages}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
ed = fetch_website_contents("https://cnn.com")
print(ed)
# Out:
# Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# ...

# %%
system_prompt = """
You are a  assistant that analyzes the contents of a website,
and provides a short, a Naija vibe, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
{"role": "system", "content": "system messages goes here"},
{"role": "user","content":"user message goes here"}
# Out:
# {'role': 'user', 'content': 'user message goes here'}

# %%
print(response.choices[0].message.content)
# Out:
# Prayer na when person dey talk to God—e fit be to ask for help, thank am, praise am, or confess sin.

# %%
#CHAT COMPLETION APIs

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact about Nigeria"}]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
import requests
import os

api_key = os.getenv("OPENAI_API_KEY")

url = "https://api.openai.com/v1/responses"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

payload = {
    "model": "gpt-5-nano",
    "input": "Tell me a fun fact"
}

response = requests.post(
    url,
    headers=headers,
    json=payload,
    timeout=30
)

print(response.status_code)
print(response.json())
# Out:
# 429
# {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
# HOMEWORK EXERCISE ASSIGNMENT
#Let's make your exact OpenAI experiment work with Ollama

# %%
import requests

url = "http://localhost:11434/api/chat"

payload = {
    "model": "gemma3:270m",
    "messages": [
        {
            "role": "user",
            "content": "Tell me a fun fact nigeria and its pigin english"
        }
    ],
    "stream": False
}

response = requests.post(
    url,
    json=payload,
    timeout=60
)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'model': 'gemma3:270m', 'created_at': '2026-09-22T13:01:50.148341402Z', 'message': {'role': 'assistant', 'content': 'Nigeria\'s pig is called a "pigeon" because it is quite rotund.\n'}, 'done': True, 'done_reason': 'stop', 'total_duration': 54518520394, 'load_duration': 46354158987, 'prompt_eval_count': 20, 'prompt_eval_cached_count': 0, 'prompt_eval_duration': 5937094000, 'eval_count': 19, 'eval_duration': 703973000}

# %%
data = response.json()

print(data["message"]["content"])
# Out:
# Nigeria's pig is called a "pigeon" because it is quite rotund.

# %%
#this is not true and could be probsbly the model i used lols so funny but at the end i achieved calling ollama locally for openAI i had no credit.

# %%
#trying to see the data type
print(type(data))
# Out:
# <class 'dict'>

# %%
#since it a dict i will like to see the key
print(data.keys())
# Out:
# dict_keys(['model', 'created_at', 'message', 'done', 'done_reason', 'total_duration', 'load_duration', 'prompt_eval_count', 'prompt_eval_cached_count', 'prompt_eval_duration', 'eval_count', 'eval_duration'])

# %%
print(data["message"])
# Out:
# {'role': 'assistant', 'content': 'Nigeria\'s pig is called a "pigeon" because it is quite rotund.\n'}

# %%
print(data["message"]["content"])
# Out:
# Nigeria's pig is called a "pigeon" because it is quite rotund.

# %%
###USING OPENAI PACKAGE
#Python Client Library

# %%
#create openAI client
from openai import OpenAI
openai = OpenAI()

reponse = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "tell me a fun fact about nigeria"}])

response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 5
#       1 #create openAI client
#       2 from openai import OpenAI
#       3 openai = OpenAI()
#       4
# ----> 5 reponse = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "tell me a fun fact about nigeria"}])
#       6
#       7 response.choices[0].message.content
#
# File ~/llm_Projects/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
#RUNNING OLLAMA LOCALY ON CHAT COMPLETION
#Ollama also gives a OpenAI compatible endpoint

# %%
from openai import OpenAI
import ollama

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠇ pulling manifest ⠋ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# ...

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
response = ollama.chat.completions.create(
    model="gemma3:270m",
    messages=[
        {
            "role": "user",
            "content": "Hello! Tell me a fun fact."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Okay, here's a fun fact:
#
# Did you know that the Amazon rainforest is home to an incredible array of amazing creatures, including sloths, monkeys, and even the possibility of flying, and even the possibility of life on Mars?

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is Avalumun Sekulla Nyior and I like towu or luam")

# %%
tokens
# Out:
# [12194,
#  922,
#  1308,
#  382,
#  63004,
#  394,
#  373,
#  35553,
#  21917,
#  23630,
#  1878,
#  326,
#  357,
#  1299,
#  316,
#  17060,
#  503,
#  90024]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 63004 =  Aval
# 394 = um
# 373 = un
# 35553 =  Sek
# 21917 = ulla
# 23630 =  Ny
# 1878 = ior
# 326 =  and
# 357 =  I
# 1299 =  like
# 316 =  to
# 17060 = wu
# 503 =  or
# 90024 =  luam

# %%
encoding.decode([90024])
# Out:
# ' luam'

# %%
#the illusion of memory

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
from openai import OpenAI

openai = OpenAI()

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Avalumun Sekulla Nyior!"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
#       2 response.choices[0].message.content
#
# File ~/llm_Projects/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
#LET'S TRY USING OLLAMA 3.2

# %%
import ollama

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Avalumun Sekulla Nyior!"}
]

# %%
response = ollama.chat(
    model="gemma3:270m",
    messages=messages
)

# %%
print(response.message.content)
# Out:
# Hello Avalumun Sekulla Nyior! How can I help you today?

# %%
{
    "role": "user",
    "content": "My name is Avalumun. What do you know about me from this conversation?"
}
# Out:
# {'role': 'user',
#  'content': 'My name is Avalumun. What do you know about me from this conversation?'}

# %%
messages.append({
    "role": "user",
    "content": "What did I just tell you my name was?"
})

# %%
print(response.messages.content)

# %%
messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant."
    }
]

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Assistant: Goodbye!")
        break

    messages.append({
        "role": "user",
        "content": user_input
    })

    response = ollama.chat(
        model="gemma3:270m",
        messages=messages
    )

    assistant_message = response.message.content

    print("Assistant:", assistant_message)

    messages.append({
        "role": "assistant",
        "content": assistant_message
    })
